# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import time
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=3000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=3000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 987

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(20)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_currdisc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_currdisc})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | saint-pierre
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | garden city
# Processing Record 5 of Set 1 | faanui
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | ridgecrest
# Processing Record 8 of Set 1 | talnakh
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | skala
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | high level
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | salvador
# Processing Record 17 of Set 1 | baruun-urt
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | gadung
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | chokurdakh
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | lambarene
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | montrose
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | lima
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | lorengau
# Processing Record 39 of Set 1 | batticaloa
# Processing Record 40 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | kakhun
# Processing Record 43 of Set 1 | port elizabeth
# Processing Record 44 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 1 | leningradskiy
# Processing Record 46 of Set 1 | cabo san lucas
# Processing Record 47 of Set 1 | bambous virieux
# Processing Record 48 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 1 | yarke pole
# Processing Record 50 of Set 1 | rodeo
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | pangnirtung
# Processing Record 5 of Set 2 | norman wells
# Processing Record 6 of Set 2 | katsuura
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 2 | columbus
# Processing Record 11 of Set 2 | carutapera
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | guerrero negro
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | wencheng
# Processing Record 17 of Set 2 | auki
# Processing Record 18 of Set 2 | surovikino
# Processing Record 19 of Set 2 | yuci
# Processing Record 20 of Set 2 | hilton head island
# Processing Record 21 of Set 2 | puerto ayora
# Processing Record 22 of Set 2 | pacifica
# Processing Record 23 of Set 2 | gamba
# Processing Record 24 of Set 2 | bathsheba
# Processing Record 25 of Set 2 | castro
# Processing Record 26 of Set 2 | oktyabrskoye
# Processing Record 27 of Set 2 | qaqortoq
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | key west
# Processing Record 30 of Set 2 | preobrazheniye
# Processing Record 31 of Set 2 | lagoa
# Processing Record 32 of Set 2 | pevek
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | te anau
# Processing Record 35 of Set 2 | maridi
# Processing Record 36 of Set 2 | saint anthony
# Processing Record 37 of Set 2 | aklavik
# Processing Record 38 of Set 2 | rio gallegos
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | henties bay
# Processing Record 41 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | paka
# Processing Record 44 of Set 2 | sola
# Processing Record 45 of Set 2 | puerto colombia
# Processing Record 46 of Set 2 | ashibetsu
# Processing Record 47 of Set 2 | yulara
# Processing Record 48 of Set 2 | falmouth
# Processing Record 49 of Set 2 | torbay
# Processing Record 50 of Set 2 | aknada
# Processing Record 1 of Set 3 | quebo
# Processing Record 2 of Set 3 | ambunti
# Processing Record 3 of Set 3 | lompoc
# Processing Record 4 of Set 3 | ketchikan
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | kapaa
# Processing Record 7 of Set 3 | big rapids
# Processing Record 8 of Set 3 | shache
# Processing Record 9 of Set 3 | baracoa
# Processing Record 10 of Set 3 | aden
# Processing Record 11 of Set 3 | lavrentiya
# Processing Record 12 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 13 of Set 3 | valle de allende
# Processing Record 14 of Set 3 | padang
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | puerto berrio
# Processing Record 17 of Set 3 | nuuk
# Processing Record 18 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 3 | ust-nera
# Processing Record 20 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | walvis bay
# Processing Record 23 of Set 3 | batagay
# Processing Record 24 of Set 3 | ayagoz
# Processing Record 25 of Set 3 | tagusao
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | bourail
# Processing Record 28 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 3 | hovd
# Processing Record 30 of Set 3 | san patricio
# Processing Record 31 of Set 3 | ahualulco
# Processing Record 32 of Set 3 | mount gambier
# Processing Record 33 of Set 3 | kirkwall
# Processing Record 34 of Set 3 | saldanha
# Processing Record 35 of Set 3 | suratgarh
# Processing Record 36 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 3 | rio grande
# Processing Record 38 of Set 3 | benjamin aceval
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | belaya gora
# Processing Record 41 of Set 3 | port blair
# Processing Record 42 of Set 3 | sulejowek
# Processing Record 43 of Set 3 | cervo
# Processing Record 44 of Set 3 | marzuq
# Processing Record 45 of Set 3 | talcahuano
# Processing Record 46 of Set 3 | hithadhoo
# Processing Record 47 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 48 of Set 3 | athabasca
# Processing Record 49 of Set 3 | yorkton
# Processing Record 50 of Set 3 | san juan
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | agadir
# Processing Record 3 of Set 4 | biak
# Processing Record 4 of Set 4 | rocha
# Processing Record 5 of Set 4 | inuvik
# Processing Record 6 of Set 4 | asau
# Processing Record 7 of Set 4 | stornoway
# Processing Record 8 of Set 4 | florianopolis
# Processing Record 9 of Set 4 | hobart
# Processing Record 10 of Set 4 | lebu
# Processing Record 11 of Set 4 | polyarnyye zori
# Processing Record 12 of Set 4 | karlshamn
# Processing Record 13 of Set 4 | san alberto
# Processing Record 14 of Set 4 | samarai
# Processing Record 15 of Set 4 | murindo
# Processing Record 16 of Set 4 | hualmay
# Processing Record 17 of Set 4 | zapresic
# Processing Record 18 of Set 4 | maniitsoq
# Processing Record 19 of Set 4 | burnie
# Processing Record 20 of Set 4 | santa cruz
# Processing Record 21 of Set 4 | dongying
# Processing Record 22 of Set 4 | mazamari
# Processing Record 23 of Set 4 | souillac
# Processing Record 24 of Set 4 | taltal
# Processing Record 25 of Set 4 | ribeira grande
# Processing Record 26 of Set 4 | cheney
# Processing Record 27 of Set 4 | dongsheng
# Processing Record 28 of Set 4 | nioro
# Processing Record 29 of Set 4 | cape canaveral
# Processing Record 30 of Set 4 | fairbanks
# Processing Record 31 of Set 4 | ahuimanu
# Processing Record 32 of Set 4 | ayan
# Processing Record 33 of Set 4 | westport
# Processing Record 34 of Set 4 | grabouw
# Processing Record 35 of Set 4 | urucara
# Processing Record 36 of Set 4 | mogadishu
# Processing Record 37 of Set 4 | nyuksenitsa
# Processing Record 38 of Set 4 | klaksvik
# Processing Record 39 of Set 4 | bengkulu
# Processing Record 40 of Set 4 | maraa
# Processing Record 41 of Set 4 | omutinskoye
# City not found. Skipping...
# Processing Record 42 of Set 4 | bandarbeyla
# Processing Record 43 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 4 | coquimbo
# Processing Record 45 of Set 4 | broken hill
# Processing Record 46 of Set 4 | omboue
# Processing Record 47 of Set 4 | ponta do sol
# Processing Record 48 of Set 4 | lazaro cardenas
# Processing Record 49 of Set 4 | missoula
# Processing Record 50 of Set 4 | bowen
# Processing Record 1 of Set 5 | muroto
# Processing Record 2 of Set 5 | mareeba
# Processing Record 3 of Set 5 | naryan-mar
# Processing Record 4 of Set 5 | naze
# Processing Record 5 of Set 5 | palmer
# Processing Record 6 of Set 5 | khatanga
# Processing Record 7 of Set 5 | bunia
# Processing Record 8 of Set 5 | gzhatsk
# City not found. Skipping...
# Processing Record 9 of Set 5 | camacha
# Processing Record 10 of Set 5 | zonguldak
# Processing Record 11 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 5 | mosquera
# Processing Record 13 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 5 | leku
# Processing Record 15 of Set 5 | esperance
# Processing Record 16 of Set 5 | jumla
# Processing Record 17 of Set 5 | praia
# Processing Record 18 of Set 5 | pundaguitan
# Processing Record 19 of Set 5 | mixco
# Processing Record 20 of Set 5 | haines junction
# Processing Record 21 of Set 5 | biryusinsk
# Processing Record 22 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 23 of Set 5 | moron
# Processing Record 24 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 25 of Set 5 | yumen
# Processing Record 26 of Set 5 | port lincoln
# Processing Record 27 of Set 5 | kisangani
# Processing Record 28 of Set 5 | muros
# Processing Record 29 of Set 5 | ostrovnoy
# Processing Record 30 of Set 5 | kodino
# Processing Record 31 of Set 5 | udachnyy
# Processing Record 32 of Set 5 | vila
# Processing Record 33 of Set 5 | bournemouth
# Processing Record 34 of Set 5 | kapit
# Processing Record 35 of Set 5 | caravelas
# Processing Record 36 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 5 | hamilton
# Processing Record 38 of Set 5 | grass valley
# Processing Record 39 of Set 5 | maldonado
# Processing Record 40 of Set 5 | vostok
# Processing Record 41 of Set 5 | syracuse
# Processing Record 42 of Set 5 | bud
# Processing Record 43 of Set 5 | ericeira
# Processing Record 44 of Set 5 | kuah
# Processing Record 45 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 5 | morant bay
# Processing Record 47 of Set 5 | kargapolye
# City not found. Skipping...
# Processing Record 48 of Set 5 | labrea
# Processing Record 49 of Set 5 | garm
# City not found. Skipping...
# Processing Record 50 of Set 5 | uhlove
# Processing Record 1 of Set 6 | baixo guandu
# Processing Record 2 of Set 6 | mayor pablo lagerenza
# Processing Record 3 of Set 6 | arlit
# Processing Record 4 of Set 6 | bayir
# Processing Record 5 of Set 6 | roma
# Processing Record 6 of Set 6 | sacramento
# Processing Record 7 of Set 6 | eisenhuttenstadt
# City not found. Skipping...
# Processing Record 8 of Set 6 | lasa
# Processing Record 9 of Set 6 | beringovskiy
# Processing Record 10 of Set 6 | puerto montt
# Processing Record 11 of Set 6 | lethem
# Processing Record 12 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 6 | harboore
# Processing Record 14 of Set 6 | vung tau
# Processing Record 15 of Set 6 | kalmar
# Processing Record 16 of Set 6 | sambava
# Processing Record 17 of Set 6 | cidreira
# Processing Record 18 of Set 6 | zuwarah
# Processing Record 19 of Set 6 | kruisfontein
# Processing Record 20 of Set 6 | sur
# Processing Record 21 of Set 6 | tananger
# Processing Record 22 of Set 6 | bethel
# Processing Record 23 of Set 6 | mchinji
# Processing Record 24 of Set 6 | komsomolskiy
# Processing Record 25 of Set 6 | dzaoudzi
# Processing Record 26 of Set 6 | churapcha
# Processing Record 27 of Set 6 | laoag
# Processing Record 28 of Set 6 | severo-kurilsk
# Processing Record 29 of Set 6 | touros
# Processing Record 30 of Set 6 | ginir
# Processing Record 31 of Set 6 | san carlos de bariloche
# Processing Record 32 of Set 6 | ancud
# Processing Record 33 of Set 6 | san policarpo
# Processing Record 34 of Set 6 | iqaluit
# Processing Record 35 of Set 6 | victoria
# Processing Record 36 of Set 6 | nikolskoye
# Processing Record 37 of Set 6 | bati
# Processing Record 38 of Set 6 | northam
# Processing Record 39 of Set 6 | nabire
# Processing Record 40 of Set 6 | ambilobe
# Processing Record 41 of Set 6 | urumqi
# Processing Record 42 of Set 6 | serov
# Processing Record 43 of Set 6 | barkhan
# Processing Record 44 of Set 6 | sinnamary
# Processing Record 45 of Set 6 | sitka
# Processing Record 46 of Set 6 | dingle
# Processing Record 47 of Set 6 | nastola
# Processing Record 48 of Set 6 | deputatskiy
# Processing Record 49 of Set 6 | sankeshwar
# Processing Record 50 of Set 6 | pithoragarh
# Processing Record 1 of Set 7 | kudahuvadhoo
# Processing Record 2 of Set 7 | salme
# Processing Record 3 of Set 7 | kuytun
# Processing Record 4 of Set 7 | conde
# Processing Record 5 of Set 7 | boa vista
# Processing Record 6 of Set 7 | lanzhou
# Processing Record 7 of Set 7 | kavieng
# Processing Record 8 of Set 7 | kozachi laheri
# Processing Record 9 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 10 of Set 7 | sungairaya
# Processing Record 11 of Set 7 | deh rawud
# City not found. Skipping...
# Processing Record 12 of Set 7 | tura
# Processing Record 13 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 7 | songjianghe
# Processing Record 15 of Set 7 | watsa
# Processing Record 16 of Set 7 | dinar
# Processing Record 17 of Set 7 | evensk
# Processing Record 18 of Set 7 | gambela
# Processing Record 19 of Set 7 | algiers
# Processing Record 20 of Set 7 | meulaboh
# Processing Record 21 of Set 7 | tuatapere
# Processing Record 22 of Set 7 | mahibadhoo
# Processing Record 23 of Set 7 | luwuk
# Processing Record 24 of Set 7 | baie-comeau
# Processing Record 25 of Set 7 | sangar
# Processing Record 26 of Set 7 | portland
# Processing Record 27 of Set 7 | mehamn
# Processing Record 28 of Set 7 | longyearbyen
# Processing Record 29 of Set 7 | moroto
# Processing Record 30 of Set 7 | rusape
# Processing Record 31 of Set 7 | butaritari
# Processing Record 32 of Set 7 | nouakchott
# Processing Record 33 of Set 7 | kuala lipis
# Processing Record 34 of Set 7 | orange
# Processing Record 35 of Set 7 | sorland
# Processing Record 36 of Set 7 | glenwood springs
# Processing Record 37 of Set 7 | andros town
# Processing Record 38 of Set 7 | sebinkarahisar
# Processing Record 39 of Set 7 | imeni poliny osipenko
# Processing Record 40 of Set 7 | pasni
# Processing Record 41 of Set 7 | saint george
# Processing Record 42 of Set 7 | namatanai
# Processing Record 43 of Set 7 | beira
# Processing Record 44 of Set 7 | nelson bay
# Processing Record 45 of Set 7 | tessalit
# Processing Record 46 of Set 7 | aitape
# Processing Record 47 of Set 7 | sao filipe
# Processing Record 48 of Set 7 | emet
# Processing Record 49 of Set 7 | rawson
# Processing Record 50 of Set 7 | north bend
# Processing Record 1 of Set 8 | solok
# Processing Record 2 of Set 8 | san cristobal
# Processing Record 3 of Set 8 | kulhudhuffushi
# Processing Record 4 of Set 8 | fengcheng
# Processing Record 5 of Set 8 | parfino
# Processing Record 6 of Set 8 | fayaoue
# Processing Record 7 of Set 8 | jiwani
# Processing Record 8 of Set 8 | kavaratti
# Processing Record 9 of Set 8 | byron bay
# Processing Record 10 of Set 8 | formosa do rio preto
# Processing Record 11 of Set 8 | calvinia
# Processing Record 12 of Set 8 | aldergrove
# Processing Record 13 of Set 8 | adrar
# Processing Record 14 of Set 8 | los llanos de aridane
# Processing Record 15 of Set 8 | mahajanga
# Processing Record 16 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 8 | lakes entrance
# Processing Record 18 of Set 8 | isangel
# Processing Record 19 of Set 8 | preston
# Processing Record 20 of Set 8 | maloyaz
# City not found. Skipping...
# Processing Record 21 of Set 8 | adelaide
# Processing Record 22 of Set 8 | mala
# Processing Record 23 of Set 8 | bulgan
# Processing Record 24 of Set 8 | mayo
# Processing Record 25 of Set 8 | luan
# Processing Record 26 of Set 8 | xunchang
# Processing Record 27 of Set 8 | pierre
# Processing Record 28 of Set 8 | luderitz
# Processing Record 29 of Set 8 | guiong
# Processing Record 30 of Set 8 | wynyard
# Processing Record 31 of Set 8 | polunochnoye
# Processing Record 32 of Set 8 | matara
# Processing Record 33 of Set 8 | labuhan
# Processing Record 34 of Set 8 | sturgeon bay
# Processing Record 35 of Set 8 | salalah
# Processing Record 36 of Set 8 | airai
# Processing Record 37 of Set 8 | nantucket
# Processing Record 38 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 8 | russell
# Processing Record 40 of Set 8 | sao felix do xingu
# Processing Record 41 of Set 8 | vanderhoof
# Processing Record 42 of Set 8 | chumikan
# Processing Record 43 of Set 8 | kungurtug
# Processing Record 44 of Set 8 | kaitangata
# Processing Record 45 of Set 8 | knysna
# Processing Record 46 of Set 8 | srednekolymsk
# Processing Record 47 of Set 8 | mandiana
# Processing Record 48 of Set 8 | mangrol
# Processing Record 49 of Set 8 | hammond
# Processing Record 50 of Set 8 | manama
# Processing Record 1 of Set 9 | juneau
# Processing Record 2 of Set 9 | harper
# Processing Record 3 of Set 9 | port shepstone
# Processing Record 4 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 9 | playas
# Processing Record 6 of Set 9 | kitimat
# Processing Record 7 of Set 9 | devarkonda
# Processing Record 8 of Set 9 | saint peters
# Processing Record 9 of Set 9 | bonthe
# Processing Record 10 of Set 9 | wakkanai
# Processing Record 11 of Set 9 | anna
# Processing Record 12 of Set 9 | luxor
# Processing Record 13 of Set 9 | mount isa
# Processing Record 14 of Set 9 | vanavara
# Processing Record 15 of Set 9 | oranjestad
# Processing Record 16 of Set 9 | balaguer
# Processing Record 17 of Set 9 | vao
# Processing Record 18 of Set 9 | marathon
# Processing Record 19 of Set 9 | sabang
# Processing Record 20 of Set 9 | pisco
# Processing Record 21 of Set 9 | morro bay
# Processing Record 22 of Set 9 | royan
# Processing Record 23 of Set 9 | mbumi
# Processing Record 24 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 25 of Set 9 | mudanya
# Processing Record 26 of Set 9 | pendleton
# Processing Record 27 of Set 9 | nador
# Processing Record 28 of Set 9 | porto novo
# Processing Record 29 of Set 9 | marawi
# Processing Record 30 of Set 9 | la palma
# Processing Record 31 of Set 9 | skelleftea
# Processing Record 32 of Set 9 | castellammare del golfo
# Processing Record 33 of Set 9 | zeya
# Processing Record 34 of Set 9 | namibe
# Processing Record 35 of Set 9 | coswig
# Processing Record 36 of Set 9 | cockburn town
# Processing Record 37 of Set 9 | isoka
# Processing Record 38 of Set 9 | monte gordo
# Processing Record 39 of Set 9 | geraldton
# Processing Record 40 of Set 9 | comodoro rivadavia
# Processing Record 41 of Set 9 | tandil
# Processing Record 42 of Set 9 | la asuncion
# Processing Record 43 of Set 9 | aasiaat
# Processing Record 44 of Set 9 | morrope
# Processing Record 45 of Set 9 | gravina in puglia
# Processing Record 46 of Set 9 | mecca
# Processing Record 47 of Set 9 | dunedin
# Processing Record 48 of Set 9 | gravdal
# Processing Record 49 of Set 9 | kailua
# Processing Record 50 of Set 9 | half moon bay
# Processing Record 1 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 10 | sokoto
# Processing Record 4 of Set 10 | santiago de cao
# Processing Record 5 of Set 10 | jibuti
# Processing Record 6 of Set 10 | alice springs
# Processing Record 7 of Set 10 | olenegorsk
# Processing Record 8 of Set 10 | rincon
# Processing Record 9 of Set 10 | el balyana
# City not found. Skipping...
# Processing Record 10 of Set 10 | lata
# Processing Record 11 of Set 10 | itarema
# Processing Record 12 of Set 10 | qobustan
# Processing Record 13 of Set 10 | alekseyevsk
# Processing Record 14 of Set 10 | zadar
# Processing Record 15 of Set 10 | nouadhibou
# Processing Record 16 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 10 | atbasar
# Processing Record 18 of Set 10 | djambala
# Processing Record 19 of Set 10 | pacific grove
# Processing Record 20 of Set 10 | antequera
# Processing Record 21 of Set 10 | praya
# Processing Record 22 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 10 | manggar
# Processing Record 24 of Set 10 | nemuro
# Processing Record 25 of Set 10 | necochea
# Processing Record 26 of Set 10 | narsaq
# Processing Record 27 of Set 10 | yusva
# City not found. Skipping...
# Processing Record 28 of Set 10 | codrington
# Processing Record 29 of Set 10 | jalu
# Processing Record 30 of Set 10 | yago
# Processing Record 31 of Set 10 | biggar
# Processing Record 32 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 10 | mana
# Processing Record 34 of Set 10 | wukari
# Processing Record 35 of Set 10 | manitouwadge
# Processing Record 36 of Set 10 | bubaque
# Processing Record 37 of Set 10 | hambantota
# Processing Record 38 of Set 10 | kincardine
# Processing Record 39 of Set 10 | helden
# Processing Record 40 of Set 10 | karratha
# Processing Record 41 of Set 10 | shingu
# Processing Record 42 of Set 10 | bukachacha
# Processing Record 43 of Set 10 | chernyshevskiy
# Processing Record 44 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 45 of Set 10 | anshun
# Processing Record 46 of Set 10 | gberia fotombu
# Processing Record 47 of Set 10 | ust-ishim
# Processing Record 48 of Set 10 | turtas
# Processing Record 49 of Set 10 | hun
# Processing Record 50 of Set 10 | shar
# Processing Record 1 of Set 11 | new cumnock
# Processing Record 2 of Set 11 | castano primo
# Processing Record 3 of Set 11 | viedma
# Processing Record 4 of Set 11 | uzhur
# Processing Record 5 of Set 11 | nautla
# Processing Record 6 of Set 11 | osypenko
# Processing Record 7 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 11 | ballina
# Processing Record 9 of Set 11 | unai
# Processing Record 10 of Set 11 | acuna
# City not found. Skipping...
# Processing Record 11 of Set 11 | siavonga
# Processing Record 12 of Set 11 | pampierstad
# Processing Record 13 of Set 11 | ilulissat
# Processing Record 14 of Set 11 | kupang
# Processing Record 15 of Set 11 | kindu
# Processing Record 16 of Set 11 | batsfjord
# Processing Record 17 of Set 11 | tabarqah
# City not found. Skipping...
# Processing Record 18 of Set 11 | borogontsy
# Processing Record 19 of Set 11 | saint-augustin
# Processing Record 20 of Set 11 | bilma
# Processing Record 21 of Set 11 | homer
# Processing Record 22 of Set 11 | yarega
# Processing Record 23 of Set 11 | kununurra
# Processing Record 24 of Set 11 | neryungri
# Processing Record 25 of Set 11 | pampas
# Processing Record 26 of Set 11 | kuito
# Processing Record 27 of Set 11 | sisimiut
# Processing Record 28 of Set 11 | owando
# Processing Record 29 of Set 11 | tual
# Processing Record 30 of Set 11 | port hedland
# Processing Record 31 of Set 11 | townsville
# Processing Record 32 of Set 11 | kinarut
# Processing Record 33 of Set 11 | belluru
# Processing Record 34 of Set 11 | piombino
# Processing Record 35 of Set 11 | emba
# Processing Record 36 of Set 11 | yanam
# Processing Record 37 of Set 11 | blagoyevo
# Processing Record 38 of Set 11 | ekibastuz
# Processing Record 39 of Set 11 | snezhnogorsk
# Processing Record 40 of Set 11 | luckenwalde
# Processing Record 41 of Set 11 | tilichiki
# Processing Record 42 of Set 11 | shieli
# Processing Record 43 of Set 11 | novo aripuana
# Processing Record 44 of Set 11 | praia da vitoria
# Processing Record 45 of Set 11 | chenzhou
# Processing Record 46 of Set 11 | siauliai
# Processing Record 47 of Set 11 | ibiruba
# Processing Record 48 of Set 11 | watertown
# Processing Record 49 of Set 11 | san pedro
# Processing Record 50 of Set 11 | dinguiraye
# Processing Record 1 of Set 12 | hobyo
# Processing Record 2 of Set 12 | escanaba
# Processing Record 3 of Set 12 | tharrawaddy
# City not found. Skipping...
# Processing Record 4 of Set 12 | laguna
# Processing Record 5 of Set 12 | vilyuysk
# Processing Record 6 of Set 12 | college
# Processing Record 7 of Set 12 | tatawin
# Processing Record 8 of Set 12 | najran
# Processing Record 9 of Set 12 | batemans bay
# Processing Record 10 of Set 12 | itatinga
# Processing Record 11 of Set 12 | paita
# Processing Record 12 of Set 12 | tautira
# Processing Record 13 of Set 12 | constitucion
# Processing Record 14 of Set 12 | palana
# Processing Record 15 of Set 12 | thinadhoo
# Processing Record 16 of Set 12 | sangmelima
# Processing Record 17 of Set 12 | kozan
# Processing Record 18 of Set 12 | yermakovskoye
# Processing Record 19 of Set 12 | machilipatnam
# Processing Record 20 of Set 12 | upington
# Processing Record 21 of Set 12 | kendari
# Processing Record 22 of Set 12 | filingue
# Processing Record 23 of Set 12 | zhaotong
# Processing Record 24 of Set 12 | road town
# Processing Record 25 of Set 12 | maham
# Processing Record 26 of Set 12 | orasac
# Processing Record 27 of Set 12 | sanwer
# Processing Record 28 of Set 12 | qiryat yam
# Processing Record 29 of Set 12 | sao gabriel da cachoeira
# Processing Record 30 of Set 12 | berlevag
# Processing Record 31 of Set 12 | pascagoula
# Processing Record 32 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 33 of Set 12 | nikolayevskaya
# Processing Record 34 of Set 12 | tunxi
# City not found. Skipping...
# Processing Record 35 of Set 12 | vila franca do campo
# Processing Record 36 of Set 12 | berezovyy
# Processing Record 37 of Set 12 | zhigansk
# Processing Record 38 of Set 12 | bambanglipuro
# Processing Record 39 of Set 12 | belyy yar
# Processing Record 40 of Set 12 | keetmanshoop
# Processing Record 41 of Set 12 | alofi
# Processing Record 42 of Set 12 | marsa matruh
# Processing Record 43 of Set 12 | lourdes
# Processing Record 44 of Set 12 | taoudenni
# Processing Record 45 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 12 | svetlogorsk
# Processing Record 47 of Set 12 | tabuk
# Processing Record 48 of Set 12 | bintulu
# Processing Record 49 of Set 12 | olinda
# Processing Record 50 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 13 | roswell
# Processing Record 2 of Set 13 | yatou
# Processing Record 3 of Set 13 | vestmanna
# Processing Record 4 of Set 13 | sao joao da barra
# Processing Record 5 of Set 13 | asosa
# Processing Record 6 of Set 13 | olafsvik
# Processing Record 7 of Set 13 | usogorsk
# Processing Record 8 of Set 13 | aberdour
# Processing Record 9 of Set 13 | daru
# Processing Record 10 of Set 13 | sabancuy
# Processing Record 11 of Set 13 | ojinaga
# Processing Record 12 of Set 13 | nyurba
# Processing Record 13 of Set 13 | hervey bay
# Processing Record 14 of Set 13 | manzhouli
# Processing Record 15 of Set 13 | phalaborwa
# Processing Record 16 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 17 of Set 13 | ouallam
# Processing Record 18 of Set 13 | oksfjord
# Processing Record 19 of Set 13 | dedza
# Processing Record 20 of Set 13 | marrakesh
# Processing Record 21 of Set 13 | eureka
# Processing Record 22 of Set 13 | sept-iles
# Processing Record 23 of Set 13 | eyl
# Processing Record 24 of Set 13 | springbok
# Processing Record 25 of Set 13 | elbistan
# Processing Record 26 of Set 13 | havre-saint-pierre
# Processing Record 27 of Set 13 | hofn
# Processing Record 28 of Set 13 | charlestown
# Processing Record 29 of Set 13 | owen sound
# Processing Record 30 of Set 13 | ayr
# Processing Record 31 of Set 13 | pochutla
# Processing Record 32 of Set 13 | verkhoyansk
# Processing Record 33 of Set 13 | saint-louis
# Processing Record 34 of Set 13 | zhangye
# Processing Record 35 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 36 of Set 13 | joshimath
# Processing Record 37 of Set 13 | karpogory
# Processing Record 38 of Set 13 | zhezkazgan
# Processing Record 39 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 13 | broome
# Processing Record 41 of Set 13 | hammerfest
# Processing Record 42 of Set 13 | plettenberg bay
# Processing Record 43 of Set 13 | khalkhal
# Processing Record 44 of Set 13 | codajas
# Processing Record 45 of Set 13 | paranagua
# Processing Record 46 of Set 13 | balkanabat
# Processing Record 47 of Set 13 | merauke
# Processing Record 48 of Set 13 | khani
# Processing Record 49 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 13 | darhan
# Processing Record 1 of Set 14 | chimay
# Processing Record 2 of Set 14 | vila velha
# Processing Record 3 of Set 14 | batagay-alyta
# Processing Record 4 of Set 14 | yar-sale
# Processing Record 5 of Set 14 | mitsamiouli
# Processing Record 6 of Set 14 | buchanan
# Processing Record 7 of Set 14 | ye
# City not found. Skipping...
# Processing Record 8 of Set 14 | kaniama
# Processing Record 9 of Set 14 | avera
# Processing Record 10 of Set 14 | terney
# Processing Record 11 of Set 14 | ygatimi
# Processing Record 12 of Set 14 | hasaki
# Processing Record 13 of Set 14 | margate
# Processing Record 14 of Set 14 | kandrian
# Processing Record 15 of Set 14 | ringas
# Processing Record 16 of Set 14 | coolum beach
# Processing Record 17 of Set 14 | mazyr
# Processing Record 18 of Set 14 | san quintin
# Processing Record 19 of Set 14 | khomutovo
# Processing Record 20 of Set 14 | storrs
# Processing Record 21 of Set 14 | avon
# Processing Record 22 of Set 14 | kastrakion
# Processing Record 23 of Set 14 | shimoda
# Processing Record 24 of Set 14 | talavera de la reina
# Processing Record 25 of Set 14 | zatoka
# Processing Record 26 of Set 14 | anadyr
# Processing Record 27 of Set 14 | dongkan
# Processing Record 28 of Set 14 | ponta delgada
# Processing Record 29 of Set 14 | seoul
# Processing Record 30 of Set 14 | ambon
# Processing Record 31 of Set 14 | puerto lempira
# Processing Record 32 of Set 14 | baffa
# Processing Record 33 of Set 14 | kondagaon
# Processing Record 34 of Set 14 | labuan
# Processing Record 35 of Set 14 | pecos
# Processing Record 36 of Set 14 | moche
# Processing Record 37 of Set 14 | havoysund
# Processing Record 38 of Set 14 | culebra
# Processing Record 39 of Set 14 | gabu
# Processing Record 40 of Set 14 | noratus
# Processing Record 41 of Set 14 | tondon
# Processing Record 42 of Set 14 | tamandare
# Processing Record 43 of Set 14 | balkhash
# Processing Record 44 of Set 14 | afgoye
# City not found. Skipping...
# Processing Record 45 of Set 14 | longhua
# Processing Record 46 of Set 14 | talaya
# Processing Record 47 of Set 14 | ilhabela
# Processing Record 48 of Set 14 | raga
# Processing Record 49 of Set 14 | aljezur
# Processing Record 50 of Set 14 | dabhol
# Processing Record 1 of Set 15 | ixtapa
# Processing Record 2 of Set 15 | molepolole
# Processing Record 3 of Set 15 | atchison
# Processing Record 4 of Set 15 | prince rupert
# Processing Record 5 of Set 15 | villa del rosario
# Processing Record 6 of Set 15 | krk
# Processing Record 7 of Set 15 | dalmatovo
# Processing Record 8 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 9 of Set 15 | tome
# Processing Record 10 of Set 15 | chaman
# Processing Record 11 of Set 15 | brae
# Processing Record 12 of Set 15 | olbia
# Processing Record 13 of Set 15 | domoni
# Processing Record 14 of Set 15 | mosjoen
# Processing Record 15 of Set 15 | saint-francois
# Processing Record 16 of Set 15 | foshan
# Processing Record 17 of Set 15 | casper
# Processing Record 18 of Set 15 | borujan
# City not found. Skipping...
# Processing Record 19 of Set 15 | ulaangom
# Processing Record 20 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 15 | iquitos
# Processing Record 22 of Set 15 | manta
# Processing Record 23 of Set 15 | rascani
# City not found. Skipping...
# Processing Record 24 of Set 15 | kasangulu
# Processing Record 25 of Set 15 | nanortalik
# Processing Record 26 of Set 15 | flinders
# Processing Record 27 of Set 15 | mayya
# Processing Record 28 of Set 15 | esna
# Processing Record 29 of Set 15 | freetown
# Processing Record 30 of Set 15 | flin flon
# Processing Record 31 of Set 15 | acari
# Processing Record 32 of Set 15 | valdepenas
# Processing Record 33 of Set 15 | sorong
# Processing Record 34 of Set 15 | camana
# Processing Record 35 of Set 15 | humaita
# Processing Record 36 of Set 15 | adzope
# Processing Record 37 of Set 15 | bonavista
# Processing Record 38 of Set 15 | lakitelek
# Processing Record 39 of Set 15 | pokaran
# Processing Record 40 of Set 15 | kangaatsiaq
# Processing Record 41 of Set 15 | svetlaya
# Processing Record 42 of Set 15 | manaure
# Processing Record 43 of Set 15 | poum
# Processing Record 44 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 45 of Set 15 | buta
# Processing Record 46 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 15 | hirara
# Processing Record 48 of Set 15 | tanabe
# Processing Record 49 of Set 15 | svetlyy
# Processing Record 50 of Set 15 | waipawa
# Processing Record 1 of Set 16 | gat
# Processing Record 2 of Set 16 | huarmey
# Processing Record 3 of Set 16 | wanning
# Processing Record 4 of Set 16 | ewa beach
# Processing Record 5 of Set 16 | chuguyevka
# Processing Record 6 of Set 16 | vanimo
# Processing Record 7 of Set 16 | nome
# Processing Record 8 of Set 16 | beloha
# Processing Record 9 of Set 16 | sault sainte marie
# Processing Record 10 of Set 16 | betare oya
# Processing Record 11 of Set 16 | kingisepp
# Processing Record 12 of Set 16 | kinston
# Processing Record 13 of Set 16 | swinford
# Processing Record 14 of Set 16 | shubarshi
# Processing Record 15 of Set 16 | manoel urbano
# Processing Record 16 of Set 16 | le vauclin
# Processing Record 17 of Set 16 | smithers
# Processing Record 18 of Set 16 | tabas
# Processing Record 19 of Set 16 | axim
# Processing Record 20 of Set 16 | la ronge
# Processing Record 21 of Set 16 | omsukchan
# Processing Record 22 of Set 16 | kaeo
# Processing Record 23 of Set 16 | betioky
# Processing Record 24 of Set 16 | santa rosalia
# Processing Record 25 of Set 16 | campbellton
# Processing Record 26 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 16 | inderborskiy
# City not found. Skipping...
# Processing Record 28 of Set 16 | benghazi
# Processing Record 29 of Set 16 | dong xoai
# Processing Record 30 of Set 16 | abatskoye
# Processing Record 31 of Set 16 | palu
# Processing Record 32 of Set 16 | ust-ilimsk
# Processing Record 33 of Set 16 | visnes
# Processing Record 34 of Set 16 | kalmunai
# Processing Record 35 of Set 16 | kyaiklat
# Processing Record 36 of Set 16 | lira
# Processing Record 37 of Set 16 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 16 | copiapo
# Processing Record 40 of Set 16 | bogande
# Processing Record 41 of Set 16 | madimba
# Processing Record 42 of Set 16 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 16 | boras
# Processing Record 44 of Set 16 | clyde river
# Processing Record 45 of Set 16 | kirakira
# Processing Record 46 of Set 16 | egvekinot
# Processing Record 47 of Set 16 | ocampo
# Processing Record 48 of Set 16 | umm kaddadah
# Processing Record 49 of Set 16 | huntingdon
# Processing Record 50 of Set 16 | abu samrah
# Processing Record 1 of Set 17 | husavik
# Processing Record 2 of Set 17 | cabatuan
# Processing Record 3 of Set 17 | puerto del rosario
# Processing Record 4 of Set 17 | macaboboni
# City not found. Skipping...
# Processing Record 5 of Set 17 | changde
# Processing Record 6 of Set 17 | yaan
# Processing Record 7 of Set 17 | bairiki
# Processing Record 8 of Set 17 | kizema
# Processing Record 9 of Set 17 | tezu
# Processing Record 10 of Set 17 | semnan
# Processing Record 11 of Set 17 | buin
# Processing Record 12 of Set 17 | port macquarie
# Processing Record 13 of Set 17 | belmonte
# Processing Record 14 of Set 17 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 17 | okhotsk
# Processing Record 16 of Set 17 | tuggurt
# City not found. Skipping...
# Processing Record 17 of Set 17 | anjozorobe
# Processing Record 18 of Set 17 | fukue
# Processing Record 19 of Set 17 | port-gentil
# Processing Record 20 of Set 17 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 17 | nara
# Processing Record 22 of Set 17 | tocopilla
# Processing Record 23 of Set 17 | taguatinga
# Processing Record 24 of Set 17 | eidsvag
# Processing Record 25 of Set 17 | ndele
# Processing Record 26 of Set 17 | horodok
# Processing Record 27 of Set 17 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 17 | am timan
# Processing Record 29 of Set 17 | penne
# Processing Record 30 of Set 17 | darnah
# Processing Record 31 of Set 17 | obukhiv
# Processing Record 32 of Set 17 | goundam
# Processing Record 33 of Set 17 | alamosa
# Processing Record 34 of Set 17 | paramonga
# Processing Record 35 of Set 17 | cayenne
# Processing Record 36 of Set 17 | rovaniemi
# Processing Record 37 of Set 17 | maimon
# City not found. Skipping...
# Processing Record 38 of Set 17 | kampot
# Processing Record 39 of Set 17 | fort nelson
# Processing Record 40 of Set 17 | amahai
# Processing Record 41 of Set 17 | ust-kulom
# Processing Record 42 of Set 17 | kastamonu
# Processing Record 43 of Set 17 | storslett
# Processing Record 44 of Set 17 | khilok
# Processing Record 45 of Set 17 | sao felipe
# Processing Record 46 of Set 17 | doka
# Processing Record 47 of Set 17 | pemangkat
# Processing Record 48 of Set 17 | winnemucca
# Processing Record 49 of Set 17 | jiazi
# Processing Record 50 of Set 17 | vuktyl
# Processing Record 1 of Set 18 | tsumeb
# Processing Record 2 of Set 18 | shubarkuduk
# Processing Record 3 of Set 18 | maunabo
# Processing Record 4 of Set 18 | mezen
# Processing Record 5 of Set 18 | clarence town
# Processing Record 6 of Set 18 | pionerskiy
# Processing Record 7 of Set 18 | ratnagiri
# Processing Record 8 of Set 18 | tucupita
# Processing Record 9 of Set 18 | kollumerland
# City not found. Skipping...
# Processing Record 10 of Set 18 | khorixas
# Processing Record 11 of Set 18 | tianpeng
# Processing Record 12 of Set 18 | amazar
# Processing Record 13 of Set 18 | boralday
# Processing Record 14 of Set 18 | karpuninskiy
# City not found. Skipping...
# Processing Record 15 of Set 18 | ellisras
# Processing Record 16 of Set 18 | tingrela
# City not found. Skipping...
# Processing Record 17 of Set 18 | kibara
# Processing Record 18 of Set 18 | suamico
# Processing Record 19 of Set 18 | kaspiyskiy
# Processing Record 20 of Set 18 | hit
# Processing Record 21 of Set 18 | calatayud
# Processing Record 22 of Set 18 | hua hin
# Processing Record 23 of Set 18 | povenets
# Processing Record 24 of Set 18 | roseburg
# Processing Record 25 of Set 18 | borazjan
# Processing Record 26 of Set 18 | antofagasta
# Processing Record 27 of Set 18 | kahului
# Processing Record 28 of Set 18 | port hardy
# Processing Record 29 of Set 18 | kijang
# Processing Record 30 of Set 18 | aborlan
# Processing Record 31 of Set 18 | izhma
# Processing Record 32 of Set 18 | general roca
# Processing Record 33 of Set 18 | baykit
# Processing Record 34 of Set 18 | falam
# Processing Record 35 of Set 18 | avrille
# Processing Record 36 of Set 18 | tigil
# Processing Record 37 of Set 18 | bull savanna
# Processing Record 38 of Set 18 | dudinka
# Processing Record 39 of Set 18 | denpasar
# Processing Record 40 of Set 18 | gedangan
# Processing Record 41 of Set 18 | saint-leu
# Processing Record 42 of Set 18 | sakakah
# Processing Record 43 of Set 18 | fort walton beach
# Processing Record 44 of Set 18 | ostersund
# Processing Record 45 of Set 18 | bestobe
# Processing Record 46 of Set 18 | uruzgan
# Processing Record 47 of Set 18 | chiampo
# Processing Record 48 of Set 18 | tuckahoe
# Processing Record 49 of Set 18 | mizan teferi
# Processing Record 50 of Set 18 | nueva gorgona
# Processing Record 1 of Set 19 | kyra
# Processing Record 2 of Set 19 | harlingen
# Processing Record 3 of Set 19 | hami
# Processing Record 4 of Set 19 | banjar
# Processing Record 5 of Set 19 | doha
# Processing Record 6 of Set 19 | thunder bay
# Processing Record 7 of Set 19 | methven
# Processing Record 8 of Set 19 | digha
# Processing Record 9 of Set 19 | harer
# Processing Record 10 of Set 19 | ubinskoye
# Processing Record 11 of Set 19 | almaznyy
# Processing Record 12 of Set 19 | arica
# Processing Record 13 of Set 19 | murdochville
# Processing Record 14 of Set 19 | umm lajj
# Processing Record 15 of Set 19 | dukat
# Processing Record 16 of Set 19 | sechura
# Processing Record 17 of Set 19 | newtownards
# Processing Record 18 of Set 19 | sioux lookout
# Processing Record 19 of Set 19 | kingsland
# Processing Record 20 of Set 19 | birao
# Processing Record 21 of Set 19 | togitsu
# Processing Record 22 of Set 19 | genhe
# Processing Record 23 of Set 19 | anupgarh
# Processing Record 24 of Set 19 | qandala
# Processing Record 25 of Set 19 | miramar
# Processing Record 26 of Set 19 | mandurah
# Processing Record 27 of Set 19 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 19 | chamba
# Processing Record 29 of Set 19 | luanda
# Processing Record 30 of Set 19 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 19 | karera
# Processing Record 32 of Set 19 | alberton
# Processing Record 33 of Set 19 | ndioum
# Processing Record 34 of Set 19 | elizabeth city
# Processing Record 35 of Set 19 | uaua
# Processing Record 36 of Set 19 | salinas
# Processing Record 37 of Set 19 | kentau
# Processing Record 38 of Set 19 | solnechnyy
# Processing Record 39 of Set 19 | saryshagan
# City not found. Skipping...
# Processing Record 40 of Set 19 | chany
# Processing Record 41 of Set 19 | araouane
# Processing Record 42 of Set 19 | krasnokamensk
# Processing Record 43 of Set 19 | nishihara
# Processing Record 44 of Set 19 | talawdi
# City not found. Skipping...
# Processing Record 45 of Set 19 | beroroha
# Processing Record 46 of Set 19 | lerwick
# Processing Record 47 of Set 19 | conceicao do araguaia
# Processing Record 48 of Set 19 | katobu
# Processing Record 49 of Set 19 | lubben
# Processing Record 50 of Set 19 | mount hagen
# Processing Record 1 of Set 20 | anta
# Processing Record 2 of Set 20 | vilhena
# Processing Record 3 of Set 20 | cocachacra
# Processing Record 4 of Set 20 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 20 | boca do acre
# Processing Record 6 of Set 20 | vardo
# Processing Record 7 of Set 20 | sokolo
# Processing Record 8 of Set 20 | hanmer springs
# Processing Record 9 of Set 20 | burns lake
# Processing Record 10 of Set 20 | phaltan
# Processing Record 11 of Set 20 | puri
# Processing Record 12 of Set 20 | sidi ali
# Processing Record 13 of Set 20 | wattegama
# Processing Record 14 of Set 20 | wagga wagga
# Processing Record 15 of Set 20 | prudentopolis
# Processing Record 16 of Set 20 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 20 | tres arroyos
# Processing Record 18 of Set 20 | makakilo city
# Processing Record 19 of Set 20 | bilibino
# Processing Record 20 of Set 20 | navolato
# Processing Record 21 of Set 20 | sarahan
# Processing Record 22 of Set 20 | polis
# Processing Record 23 of Set 20 | atar
# Processing Record 24 of Set 20 | baoqing
# Processing Record 25 of Set 20 | roald
# Processing Record 26 of Set 20 | charyshskoye
# Processing Record 27 of Set 20 | aketi
# Processing Record 28 of Set 20 | verkhnyaya inta
# Processing Record 29 of Set 20 | teteven
# Processing Record 30 of Set 20 | itum-kale
# Processing Record 31 of Set 20 | voinesti
# Processing Record 32 of Set 20 | acapulco
# Processing Record 33 of Set 20 | chaykovskaya
# Processing Record 34 of Set 20 | saint-joseph
# Processing Record 35 of Set 20 | macamic
# Processing Record 36 of Set 20 | namwala
# Processing Record 37 of Set 20 | brigantine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
df = pd.DataFrame(city_data)
df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dikson      RU  73.5069   80.5464     -5.46        98         100
# 1    Saint-Pierre      RE -21.3393   55.4781     76.91        87          75
# 2         Ushuaia      AR -54.8000  -68.3000     38.86        87         100
# 3     Garden City      US  42.3256  -83.3310     37.98        65           0
# 4          Faanui      PF -16.4833 -151.7500     81.99        69         100
# ..            ...     ...      ...       ...       ...       ...         ...
# 900  Chaykovskaya      RU  58.1279   55.5378     12.09        97          97
# 901  Saint-Joseph      RE -21.3667   55.6167     75.58        86         100
# 902       Macamic      CA  48.7502  -78.9996     14.77        98         100
# 903       Namwala      ZM -15.7504   26.4384     63.95        97         100
# 904    Brigantine      US  39.4101  -74.3646     37.00        51         100
#
#      Wind Speed Current Description
# 0         15.77     overcast clouds
# 1         13.80       broken clouds
# 2         17.27       moderate rain
# 3          8.05           clear sky
# 4          9.69     overcast clouds
# ..          ...                 ...
# 900        3.51     overcast clouds
# 901       11.90          light rain
# 902        2.48     overcast clouds
# 903        2.66     overcast clouds
# 904        3.44     overcast clouds
#
# [905 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
df.to_csv(output_data_file, index_label="City_ID")
